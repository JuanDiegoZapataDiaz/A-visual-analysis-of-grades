# %% [markdown]
# # Score report of examn 1 - 2024-I
#
# ###### This report is exclusive for professor "Dr. Name" it cointains information about the Examn 1 and students id.
# ###### Author: Juan Diego Zapata Diaz.

# %% [markdown]
# ##### This report has the following structure:
# - General comments:
# - Score distribution: total
# - Score distribution: Conceptual questions
# - Score distribution: Numerical questions
# - Interactive plot of the *score space*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.linear_model import LinearRegression
import os

# %%
pc1=pd.read_excel('pc1.xlsx')

# %% [markdown]
# # Score distribution: total

# %% [markdown]
# The total distribution shows high dispersion of scores. While the 50% of scores lies between 9 and 15.8, the median is 11. There is a clear positive asymmetry as we se the median close to the first quartile.

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 5), gridspec_kw={"height_ratios": (2, 0.5)})
fig.suptitle('Total scores examn 1', fontsize=15)
sns.histplot(data=pc1, x='total', kde=True, ax=ax[0])
ax[0].set(xlabel=None)
sns.boxplot(data=pc1, x='total', ax=ax[1])
plt.show()

# %% [markdown]
# # Score distribution: Conceptual questions

# %% [markdown]
# There is more concensus in the scores of conceptual questions as usual in this section. However looking at the boxplot we can see that the positive asymmetry is still showing up in this section.

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 5), gridspec_kw={"height_ratios": (2, 0.5)})
fig.suptitle('Conceptual questions score (out of 10 points)', fontsize=15)
sns.histplot(data=pc1, x='conceptual', kde=True, ax=ax[0])
ax[0].set(xlabel=None)
sns.boxplot(data=pc1, x='conceptual', ax=ax[1])
plt.show()

# %% [markdown]
# # Score distribution: Numerical questions

# %% [markdown]
# As we can se in the ditribution it is markedly bimodal. This indicates that we have two groups of students clearly separate by the grades in this examn. The positive asymmetry have been generated by the numerical questions in which the two groups have diferenciated a lot.

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 5), gridspec_kw={"height_ratios": (2, 0.5)})
fig.suptitle('Numerical questions score (out of 10 puntos)', fontsize=15)
sns.histplot(data=pc1, x='numerical', kde=True, ax=ax[0])
ax[0].set(xlabel=None)
sns.boxplot(data=pc1, x='numerical', ax=ax[1])
plt.show()

# %% [markdown]
# # Interactive plot of the *score space*

# %% [markdown]
# Each of the points is one student (when selected the id is shown). The concept of the *score space* is that we can see this plot as a space that discribes the class scores. In general, people who have better score in the conceptual sections have also good grading in the numerical section. Students can see where they locate in the *score space* and focus on the sections that allow them to be in a better section of this space

# %%
import plotly.express as px

# %%
# Crear un gráfico de regresión lineal con Plotly Express
fig = px.scatter(pc1, x='conceptual', y='numerical', trendline='ols', hover_name=pc1.id ,title='Scores - Time Series Econometrics 2024 - Prof. Name')
fig.update_traces(line=dict(color='red'))
fig.update_traces(marker=dict(color='blue'))
# Personalizar el estilo del gráfico
fig.update_layout(template='plotly_dark')
fig.show()
plt.show()
